# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharwagh/DLassignment1/blob/main/Imagenette.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf

import tensorflow_datasets as tfds

import numpy as np

# %%
tfds.list_builders()
# Out:
# ['abstract_reasoning',
#  'accentdb',
#  'aeslc',
#  'aflw2k3d',
#  'ag_news_subset',
#  'ai2_arc',
#  'ai2_arc_with_ir',
#  'amazon_us_reviews',
#  'anli',
#  'arc',
#  'bair_robot_pushing_small',
#  'bccd',
#  'beans',
#  'big_patent',
#  'bigearthnet',
#  'billsum',
#  'binarized_mnist',
#  'binary_alpha_digits',
#  'blimp',
#  'bool_q',
#  'c4',
#  'caltech101',
#  'caltech_birds2010',
#  'caltech_birds2011',
#  'cars196',
#  'cassava',
#  'cats_vs_dogs',
#  'celeb_a',
#  'celeb_a_hq',
#  'cfq',
#  'chexpert',
#  'cifar10',
#  'cifar100',
#  'cifar10_1',
#  'cifar10_corrupted',
#  'citrus_leaves',
#  'cityscapes',
#  'civil_comments',
#  'clevr',
#  'clic',
#  'clinc_oos',
#  'cmaterdb',
#  'cnn_dailymail',
#  'coco',
#  'coco_captions',
#  'coil100',
#  'colorectal_histology',
#  'colorectal_histology_large',
#  'common_voice',
#  'coqa',
#  'cos_e',
#  'cosmos_qa',
#  'covid19sum',
#  'crema_d',
#  'curated_breast_imaging_ddsm',
#  'cycle_gan',
#  'deep_weeds',
# ...

# %%
ds = tfds.load('imagenette/160px-v2', split='train', shuffle_files=True)
assert isinstance(ds, tf.data.Dataset)
print(ds)
# Out:
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/imagenette/160px-v2/0.1.0.incomplete6W4W19/imagenette-train.tfrecord
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/imagenette/160px-v2/0.1.0.incomplete6W4W19/imagenette-validation.tfrecord
# ...
# Dataset imagenette downloaded and prepared to /root/tensorflow_datasets/imagenette/160px-v2/0.1.0. Subsequent calls will reuse this data.
# <_OptionsDataset shapes: {image: (None, None, 3), label: ()}, types: {image: tf.uint8, label: tf.int64}>
